# %%
import pandas as pd

# %%
df = pd.read_csv('/content/eCO2mix_RTE_En-cours-TR.csv', engine='python', sep=',', encoding='utf-8')

# %%
df
# Out:
#      Unnamed: 0  Nature        Date Heures  Consommation  Unnamed: 5  \
# 0        France     NaN  2023-02-01  00:00         62429       63500
# 1        France     NaN  2023-02-01  00:15         62131       62500
# 2        France     NaN  2023-02-01  00:30         60993       61500
# 3        France     NaN  2023-02-01  00:45         59590       60750
# 4        France     NaN  2023-02-01  01:00         59122       60000
# ...         ...     ...         ...    ...           ...         ...
# 8505     France     NaN  2023-04-30  14:15         39574       39300
# 8506     France     NaN  2023-04-30  14:30         39210       39200
# 8507     France     NaN  2023-04-30  14:45         38363       38200
# 8508     France     NaN  2023-04-30  15:00         38089       37200
# 8509     France     NaN  2023-04-30  15:15         38082       36850
#
#       Unnamed: 6  Fioul  Charbon   Gaz  ...  Unnamed: 30  Hydraulique - Lacs  \
# ...

# %%
df = df.rename(columns={'Unnamed: 0': 'Périmetre', 'Unnamed: 5': 'Prevision j-1','Unnamed: 6': 'Prevision j'
,'Unnamed: 10': 'Nucléaire','Unnamed: 15': 'Bioénergies','Unnamed: 27': 'Gaz - Cogén',
 'Unnamed: 30': 'Hydraulique - Fil de l?eau + éclusée' ,'Unnamed: 33': 'Bioénergies - Déchets','Unnamed: 34': 'Bioénergies - Biomasse', 'Unnamed: 35': 'Bioénergies - Biogaz','Unnamed: 37': 'Déstockage batterie'                   }) # Rename the columns 'Valeur (TWh)' to 'Valeur' and  'Date' to 'Date_'
df
# Out:
#      Périmetre  Nature        Date Heures  Consommation  Prevision j-1  \
# 0       France     NaN  2023-02-01  00:00         62429          63500
# 1       France     NaN  2023-02-01  00:15         62131          62500
# 2       France     NaN  2023-02-01  00:30         60993          61500
# 3       France     NaN  2023-02-01  00:45         59590          60750
# 4       France     NaN  2023-02-01  01:00         59122          60000
# ...        ...     ...         ...    ...           ...            ...
# 8505    France     NaN  2023-04-30  14:15         39574          39300
# 8506    France     NaN  2023-04-30  14:30         39210          39200
# 8507    France     NaN  2023-04-30  14:45         38363          38200
# 8508    France     NaN  2023-04-30  15:00         38089          37200
# 8509    France     NaN  2023-04-30  15:15         38082          36850
#
#       Prevision j  Fioul  Charbon   Gaz  ...  \
# 0           62600    203       55  4844  ...
# ...

# %%
df=df.drop(columns=['Nature','Périmetre'])

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
numerical_features = df.select_dtypes(include=['number'])
corr = numerical_features.corr()
plt.figure(figsize=(20, 20))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Matrice de corrélation du data')

plt.show()

# %%
df=df.drop(columns=['Prevision j-1','Prevision j','Ech. physiques','Gaz - TAC', 'Gaz - Cogén', 'Gaz - CCG','Gaz', 'Ech. comm. Angleterre', 'Ech. comm. Espagne',
       'Ech. comm. Italie', 'Ech. comm. Suisse',
       'Ech. comm. Allemagne-Belgique', 'Fioul - TAC', 'Unnamed: 24',
       'Fioul - Autres',
       'Gaz - Autres', 'Hydraulique - Fil de l?eau + éclusée',
       'Hydraulique - Lacs', 'Hydraulique - STEP turbinage',
       'Bioénergies - Déchets', 'Bioénergies - Biomasse',
       'Bioénergies - Biogaz', ' Stockage batterie', 'Déstockage batterie',
       'Eolien terrestre', 'Eolien offshore'])

# %%
df.columns
# Out:
# Index(['Date', 'Heures', 'Consommation', 'Fioul', 'Charbon', 'Nucléaire',
#        'Eolien', 'Solaire', 'Hydraulique', 'Pompage', 'Bioénergies',
#        'Taux de Co2'],
#       dtype='object')

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df = df.dropna().reset_index(drop=True)

print(df)
# Out:
#            Date Heures  Consommation  Fioul  Charbon  Nucléaire  Eolien  \
# 0    2023-02-01  00:00         62429    203       55      42351    6366
# 1    2023-02-01  00:15         62131    222       56      42422    6522
# 2    2023-02-01  00:30         60993    221       54      42240    6584
# 3    2023-02-01  00:45         59590    238       55      42072    6693
# 4    2023-02-01  01:00         59122    239       55      42205    6588
# ...         ...    ...           ...    ...      ...        ...     ...
# 8505 2023-04-30  14:15         39574    144       27      28706    2397
# 8506 2023-04-30  14:30         39210    144       27      28403    2370
# 8507 2023-04-30  14:45         38363    144       26      28313    2305
# 8508 2023-04-30  15:00         38089    144       28      28154    2240
# 8509 2023-04-30  15:15         38082    144       26      28122    2247
#
#       Solaire  Hydraulique  Pompage  Bioénergies  Taux de Co2
# ...

# %%
X = df.drop(columns=['Solaire','Eolien'])
y_solaire = df['Solaire']
y_eolien = df['Eolien']

# %%
X['Year'] = X['Date'].dt.year
X['Month'] = X['Date'].dt.month
X['Day'] = X['Date'].dt.day
X = X.drop('Date', axis=1)

if isinstance(X['Heures'].iloc[0], str) and ':' in X['Heures'].iloc[0]:
    X['Hour'] = X['Heures'].str.split(':').str[0].astype(int)
    X['Minute'] = X['Heures'].str.split(':').str[1].astype(int)
    X = X.drop('Heures', axis=1)
else:
    pass

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
X_train, X_test, y_train_solaire, y_test_solaire = train_test_split(X, y_solaire, test_size=0.2, random_state=42)
X_train, X_test, y_train_eolien, y_test_eolien = train_test_split(X, y_eolien, test_size=0.2, random_state=42)

# %%
import xgboost as xgb
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score
xgb_model = XGBRegressor()

# %%
param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [3, 5, 7],
    'learning_rate': [0.001, 0.01, 0.1],
}

# %%
grid_search = GridSearchCV(estimator=xgb_model,
                           param_grid=param_grid,
                           scoring='neg_mean_squared_error',
                           cv=3,
                           verbose=1,
                           n_jobs=-1)

# %%
grid_search.fit(X_train, y_train_solaire)
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# GridSearchCV(cv=3,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
# ...

# %%
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

mse = mean_squared_error(y_test_solaire, y_pred)
r2 = r2_score(y_test_solaire, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R^2 Score: {r2}")
# Out:
# Mean Squared Error: 73190.49219792282
# R^2 Score: 0.9925783276557922

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

current_time = datetime.now()
time_index = [current_time + timedelta(hours=i) for i in range(24)]
features_next_24h = pd.DataFrame({
    'Consommation': [0] * 24,
    'Fioul': [0] * 24,
    'Charbon': [0] * 24,
    'Nucléaire': [0] * 24,
    'Hydraulique': [0] * 24,
    'Pompage': [0] * 24,
    'Bioénergies': [0] * 24,
    'Taux de Co2': [0] * 24,
    'Year': [t.year for t in time_index],
    'Month': [t.month for t in time_index],
    'Day': [t.day for t in time_index],
    'Hour': [t.hour for t in time_index],
    'Minute': [t.minute for t in time_index]
})

features_next_24h = features_next_24h[['Consommation', 'Fioul', 'Charbon', 'Nucléaire', 'Hydraulique', 'Pompage', 'Bioénergies', 'Taux de Co2', 'Year', 'Month', 'Day', 'Hour', 'Minute']]

predictions = best_model.predict(features_next_24h)

results = pd.DataFrame({
    'timestamp': time_index,
    'predicted_solar_energy': predictions
})

print(results)
# Out:
#                     timestamp  predicted_solar_energy
# 0  2024-10-21 15:36:54.477769             6537.688477
# 1  2024-10-21 16:36:54.477769             5780.503906
# 2  2024-10-21 17:36:54.477769             4453.467773
# 3  2024-10-21 18:36:54.477769             3002.882080
# 4  2024-10-21 19:36:54.477769             1243.130859
# 5  2024-10-21 20:36:54.477769              478.731750
# 6  2024-10-21 21:36:54.477769              230.545242
# 7  2024-10-21 22:36:54.477769              222.856522
# 8  2024-10-21 23:36:54.477769              222.856522
# 9  2024-10-22 00:36:54.477769               66.716431
# 10 2024-10-22 01:36:54.477769               66.716431
# 11 2024-10-22 02:36:54.477769               66.716431
# 12 2024-10-22 03:36:54.477769               66.716431
# 13 2024-10-22 04:36:54.477769               66.716431
# 14 2024-10-22 05:36:54.477769               66.716431
# 15 2024-10-22 06:36:54.477769              234.986694
# ...

# %%
grid_search.fit(X_train, y_train_eolien)
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# GridSearchCV(cv=3,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
# ...

# %%
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

mse = mean_squared_error(y_test_eolien, y_pred)
r2 = r2_score(y_test_eolien, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R^2 Score: {r2}")
# Out:
# Mean Squared Error: 217659.65203131433
# R^2 Score: 0.9820427894592285

# %%
current_time = datetime.now()
time_index = [current_time + timedelta(hours=i) for i in range(24)]
features_next_24h = pd.DataFrame({
    'Consommation': [0] * 24,
    'Fioul': [0] * 24,
    'Charbon': [0] * 24,
    'Nucléaire': [0] * 24,
    'Hydraulique': [0] * 24,
    'Pompage': [0] * 24,
    'Bioénergies': [0] * 24,
    'Taux de Co2': [0] * 24,
    'Year': [t.year for t in time_index],
    'Month': [t.month for t in time_index],
    'Day': [t.day for t in time_index],
    'Hour': [t.hour for t in time_index],
    'Minute': [t.minute for t in time_index]
})


features_next_24h = features_next_24h[['Consommation', 'Fioul', 'Charbon', 'Nucléaire', 'Hydraulique', 'Pompage', 'Bioénergies', 'Taux de Co2', 'Year', 'Month', 'Day', 'Hour', 'Minute']]

predictions1 = best_model.predict(features_next_24h)

results = pd.DataFrame({
    'timestamp': time_index,
    'predicted_wind_energy': predictions1
})

print(results)
# Out:
#                     timestamp  predicted_wind_energy
# 0  2024-10-21 15:34:32.424502            6994.388184
# 1  2024-10-21 16:34:32.424502            7000.133789
# 2  2024-10-21 17:34:32.424502            6895.066895
# 3  2024-10-21 18:34:32.424502            6903.088379
# 4  2024-10-21 19:34:32.424502            6747.035156
# 5  2024-10-21 20:34:32.424502            7954.809082
# 6  2024-10-21 21:34:32.424502            7891.579590
# 7  2024-10-21 22:34:32.424502            7867.920410
# 8  2024-10-21 23:34:32.424502            7781.472168
# 9  2024-10-22 00:34:32.424502            8678.598633
# 10 2024-10-22 01:34:32.424502            8840.486328
# 11 2024-10-22 02:34:32.424502            8822.344727
# 12 2024-10-22 03:34:32.424502            8885.164062
# 13 2024-10-22 04:34:32.424502            8724.731445
# 14 2024-10-22 05:34:32.424502            8162.320312
# 15 2024-10-22 06:34:32.424502            8524.171875
# 16 2024-10-22 07:34:32.424502            8821.780273
# ...
